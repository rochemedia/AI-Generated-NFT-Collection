# %% [markdown]
# <a href="https://colab.research.google.com/github/rochemedia/AI-Generated-NFT-Collection/blob/master/Copy_of_yolor_deepsort_object_tracking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Run YOLOR + DeepSORT Object Tracking on Google Colab**
#
# YoloR with Object Tracking is really impressive. We will execute superior multi-object tracking (MOT) using DeepSOR. The classes are dependent on those that are trained with YOLOR so you won't need to train DeepSORT, only YOLOR which we cover in the course.
#
# # **Want to Become a YOLOR Expert?**
# 💻Get Started with YOLOR [Get Started](https://augmentedstartups.info/YOLOR-Get-Started). <br>
# ⭐ Download the Code at the [AI Vision Store](https://augmentedstartups.info/VisionStore)<br>
# ☕ Buy me [Chai/Coffee](https://bit.ly/BuymeaCoffeeAS)
#
# # **Tutorial**
#
# We will be implementing the following steps:
#
# 1.   Setting up Dependencies
# 2.   Download Sample Videos
# 3.   Process Sample Video
#
#
# # **About Me**
#
# [Augmented Startups](https://www.augmentedstartups.com) provides tutorials in AI Computer Vision and Augmented Reality. With over **89K subscribers** on our channel, we teach state-of-art models and build apps and projects that solve real-world problems.
#
#
# ![image:png](https://kajabi-storefronts-production.kajabi-cdn.com/kajabi-storefronts-production/sites/104576/images/Vc8nhFV6Rgmi402Wqm0Q_AugmentedStartupsSideROBOTICSNEW.png)

# %% [markdown]
# # **1. Download Dependencies**

# %%
# !pip install googledrivedownloader

# %%
from google_drive_downloader import GoogleDriveDownloader as gdd
 
#importing code files from google drive 
gdd.download_file_from_google_drive(file_id='1267Rjd0T0hJNy2LNDY0d2pLCh0A6gaXY',
                                    dest_path='./yolor+deepsort.zip',
                                    unzip=True)
 
 
#downloading requirement file
# https://drive.google.com/file/d/13f9UXyT_6xPUDye_D6ig8HjBa53UkILJ/view?usp=sharing
 
gdd.download_file_from_google_drive(file_id='18qBklo5i6tCwzrVKCZd1gDUQyBaxvX8G',
                                    dest_path='./reqs.txt')
 
#downloading sample video
gdd.download_file_from_google_drive(file_id='1Wey_K9-31W8Pu1OGPElY5CLr1BgfiLN2',
                                    dest_path='./sample.mp4')
# Out:
# ...
# Unzipping...Done.
# ...

# %% [markdown]
# **Get the Latest Updated DeepSORT Tracking Script**

# %%
# !git clone https://github.com/augmentedstartups/YOLOR-DEEPSORT-Object-Tracking.git
# !mv /content/YOLOR-DEEPSORT-Object-Tracking/detect_track_trails.py /content/yolor
# Out:
# Cloning into 'YOLOR-DEEPSORT-Object-Tracking'...
# remote: Enumerating objects: 16, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 16 (delta 2), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (16/16), done.

# %% [markdown]
# # **2. Install Requirements**

# %%
#Installing requirement files to configure the environment - Note this will take about ~10 minutes to complete.
#Ignore the errors
# !pip install -r reqs.txt
# Out:
# ...
#      |████████████████████████████████| 72 kB 759 kB/s
# ...
#      |████████████████████████████████| 156 kB 18.6 MB/s
# ...
#      |████████████████████████████████| 97 kB 9.1 MB/s
# ...
#      |████████████████████████████████| 43 kB 3.0 MB/s
# ...
#      |████████████████████████████████| 3.4 MB 60.3 MB/s
# ...
#      |████████████████████████████████| 2.0 MB 55.7 MB/s
# ...
#      |████████████████████████████████| 3.6 MB 78.4 MB/s
# ...
#      |████████████████████████████████| 294 kB 71.1 MB/s
# ...
#      |████████████████████████████████| 73 kB 2.3 MB/s
# ...
#      |████████████████████████████████| 829 kB 63.9 MB/s
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 63 kB 2.4 MB/s
# ...
#      |████████████████████████████████| 170 kB 75.8 MB/s
# ...
#      |████████████████████████████████| 136 kB 77.3 MB/s
# ...
#      |████████████████████████████████| 3.8 MB 67.7 MB/s
# ...

# %% [markdown]
# # **3. Run YOLOR + DeepSORT Object Tracking**

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
# %cd yolor

# %%
# !python detect_track_trails.py --source /content/sample.mp4 --cfg cfg/yolor_p6.cfg --weights yolor_p6.pt --conf 0.25 --img-size 1280 --device 0 #--view-img

# %%
# !mv "/content/yolor/inference/output/sample.mp4" "/content/gdrive/MyDrive/Dev/Soccer/Output"

# %% [markdown]
# Your processed files should be in **yolor/inference/output**

# %% [markdown]
# # **4. Future Work**
#
# *   Convert and Display output Video in Colab
# *   Save to GDrive

# %% [markdown]
# # **Conclusion**
#
# If you enjoyed this tutorial and want more on **YOLOR** then:
#
# 💻Get Started with YOLOR [Get Started](https://augmentedstartups.info/YOLOR-Get-Started). <br>
# ⭐ Download the Code at the [AI Vision Store](https://augmentedstartups.info/VisionStore)<br>
# ☕ Show your support with [Chai/Coffee](https://bit.ly/BuymeaCoffeeAS)
#
# ![picture](https://drive.google.com/uc?export=view&id=1ps6pORV6b4eOoQAljv8s-hTq9YAaIN3b)
